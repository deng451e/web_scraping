# %%
import requests
import bs4
res=requests.get('https://www.indeed.com/jobs?q=data+science&l=Arlington%2C+TX')
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr">\n<head>\n<meta http-equiv="content-type" content="text/html;charset=UTF-8">\n<script type="text/javascript" src="/s/cb2751b/en_US.js"></script>\n<script>window.indeed=window.indeed||{};indeed.crashtext=indeed.crashtext||{};indeed.crashtext.populate=indeed.crashtext.populate||function(c,g){var d=window[g];if(d){var e=d[""]||{},h=e.salt;if(e.hasOwnProperty("salt"))for(var b in c){for(var a=void 0,a=h,f=b.length;f;)a=33*a^b.charCodeAt(--f);a>>>=0;e.hasOwnProperty("id_length")&&(a=String(a).substring(0,e.id_length));d[a]=c[b]}else for(b in c)d[b]=[null].concat(c[b])}};indeed.crashtext.populate({"Save jobs and view them from any computer.":["Save and remind me later. "],"You must sign in to save jobs:":["Sign in to save:"]}, \'indeed.i18n.localeData\')</script>\n<link href="/s/b066150/jobsearch_all.css" rel="stylesheet" type="text/css">\n<link rel="alternate" type="application/rss+xml" title="Data Science Jobs, Employment in Arlington, TX" href
# ...

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')
for link in soup.find_all('a',href=True):
    print(link['href'])
# Out:
# #jobPostingsAnchor
# #what
# /?from=gnav-jobsearch--jasx
# https://www.indeed.com/
# https://www.indeed.com/companies
# https://www.indeed.com/salaries
# https://www.indeed.com/promo/resume
# https://secure.indeed.com/account/login?hl=en_US&co=US&continue=http%3A%2F%2Fwww.indeed.com%2Fq-data-science-l-Arlington%2C-TX-jobs.html%3Fq%3Ddata+science%26l%3DArlington%2C+TX&tmpl=desktop&service=my&from=gnav-util-jobsearch--jasx
# https://www.indeed.com/hire?co=US&hl=en
# /advanced_search?q=data+science&l=Arlington%2C+TX
# /jobs?q=data+science&l=Arlington%2C+TX&sort=date
# /q-data-science-$75,000-l-Arlington,-TX-jobs.html
# /q-data-science-$95,600-l-Arlington,-TX-jobs.html
# /q-data-science-$105,700-l-Arlington,-TX-jobs.html
# /q-data-science-$115,000-l-Arlington,-TX-jobs.html
# /q-data-science-$125,000-l-Arlington,-TX-jobs.html
# /jobs?q=data+science&l=Arlington,+TX&jt=fulltime
# /jobs?q=data+science&l=Arlington,+TX&jt=contract
# /jobs?q=data+science&l=Arlington,+TX&jt=internship
# ...
